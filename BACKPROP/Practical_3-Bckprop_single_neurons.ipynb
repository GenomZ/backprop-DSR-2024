# %% [markdown]
# # DSR - Practical 3 - Backprop on a single artificial Neuron

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np

# %%
class Perceptron:
    def __init__(self, N,alpha=0.1):
        # initialize the weight matrix and store the learning rate
        self.W = np.random.randn(N, 1)
        self.alpha = alpha
        

    def sigmoid_activation(self, x):
        # compute the sigmoid activation value for a given input
        ### ENTER YOUR CODE HERE
        

    def sigmoid_deriv(self, x):
        # compute the derivative of the sigmoid function ASSUMING
        # that the input `x` has already been passed through the sigmoid
        # activation function
         ### ENTER YOUR CODE HERE
        
    
    def predict(self,x):
              # take the dot product between our features and weight matrix
         ### ENTER YOUR CODE HERE
        pred = 
        
        return preds
            
    def fit(self, X, y,epochs):
        # initialize our weight matrix and list of losses
        print("training...")
        # loop over the desired number of epochs
        for e in np.arange(0, epochs):
            
            preds = self.predict(X)
            # now that we have our predictions, we need to determine the
            # `error`, which is the difference between our predictions and
            # the true values
            # ENTER YOUR CODE HERE
            error = 
            loss = 
            
            # the gradient descent update is the dot product between our
            # (1) features (X) and (2) the error of the sigmoid derivative of
            # our predictions
            d = error * self.sigmoid_deriv(preds)
            gradient = np.dot(X.T,d)
            # in the update stage, all we need to do is "nudge" the weight
            # matrix in the negative direction of the gradient (hence the
            # term "gradient descent" by taking a small step towards a set
            # of "more optimal" parameters
            self.W += -self.alpha * gradient
            # check to see if an update should be displayed
            if e == 0 or (e + 1) % 1 == 0:
                print("epoch= ",int(e+1),", loss= ",loss)
        pass

# %%
# generate a 2-class classification problem with 1,000 data points,
# where each data point is a 2D feature vector
(X, y) = make_blobs(n_samples=1600, n_features=2, centers=2,
cluster_std=1.5, random_state=42)
y = y.reshape((y.shape[0], 1))
plt.scatter(X[:, 0], X[:, 1], marker="o", c=y[:, 0], s=30)

# insert a column of 1's as the last entry in the feature
# matrix -- so we can train the bias as part of the weights
X = np.c_[X, np.ones((X.shape[0]))]
          
# partition the data into training and testing splits using 50% of
# the data for training and the remaining 50% for testing
(trainX, testX, trainY, testY) = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
### Modify Perceptron Class such that you save the training losses and return them

# %%
epochs = 100
alpha = 0.001
# create Perceptron object and train
p = Perceptron(3, alpha=alpha)
losses = #ENTER YOUR CODE HERE
# Out:
# training...
# epoch=  1 , loss=  0.4535250612482459
# epoch=  2 , loss=  0.4463961404889556
# epoch=  3 , loss=  0.4372539588027786
# epoch=  4 , loss=  0.4252602233548916
# epoch=  5 , loss=  0.4092057698604154
# epoch=  6 , loss=  0.3874669859082562
# epoch=  7 , loss=  0.3580944924425702
# epoch=  8 , loss=  0.3192245003858108
# epoch=  9 , loss=  0.2704980250353895
# epoch=  10 , loss=  0.21452906699855137
# epoch=  11 , loss=  0.15754811983411865
# epoch=  12 , loss=  0.11077190359136133
# epoch=  13 , loss=  0.07862275353246365
# epoch=  14 , loss=  0.05771447249516351
# epoch=  15 , loss=  0.04435682983130208
# epoch=  16 , loss=  0.035637832315241764
# epoch=  17 , loss=  0.02964280882779502
# epoch=  18 , loss=  0.025291183522641432
# epoch=  19 , loss=  0.021993683623394135
# epoch=  20 , loss=  0.01941374440508896
# epoch=  21 , loss=  0.01734578523924454
# epoch=  92 , loss=  0.002175443092431781
# epoch=  93 , loss=  0.0021572366370300957
# epoch=  94 , loss=  0.0021397649355758192
# epoch=  95 , loss=  0.0021230012957695306
# epoch=  96 , loss=  0.0021069198534306465
# epoch=  97 , loss=  0.0020914955341184874
# epoch=  98 , loss=  0.002076704018735755
# epoch=  99 , loss=  0.0020625217127316652
# epoch=  100 , loss=  0.0020489257185471125

# %%
# evaluate our model
print("evaluating...")
preds = p.predict(testX)
# apply a step function to threshold the outputs to binary
# class labe|ls
preds[preds <= 0.5] = 0
preds[preds > 0.5] = 1
print(classification_report(testY, preds))
# Out:
# evaluating...
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       403
#            1       1.00      0.99      1.00       397
#
#     accuracy                           1.00       800
#    macro avg       1.00      1.00      1.00       800
# weighted avg       1.00      1.00      1.00       800

# %%
plt.scatter(testX[:, 0], testX[:, 1], marker="o", c=testY[:, 0], s=30)

# %%
# plot the losses as function of epochs
plt.plot(np.arange(0, epochs), losses)
plt.title("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ### Gradient Descent can be very slow and wasteful
#
# If you are dealing with big data sets the computation becomes costly, yielding huge matrix calculations
# $$ W \cdot{X}   $$
#
# The following is a more efficient way to perform GD with faster convergence.
#
# ## Stochastic Gradient descent
#
# Instead of updating the weights on an entire epoch we do more updates on mini-batches of data.
# This way we have multiple updates per epoch. When we have a batch size = 16, we show the network only 16 training data points before updating its weights. The minimum possible batch size is one.
#
# #### Implement sgd in our perceptron class (batches of 16)

# %%
## enter modified Perceptron Class here

# %%
# create a perceptron object and train it save the losses as losses2 and compare the 
# losses of the current and former percptrons
epochs = 100
alpha = 0.01
p = Perceptron(3, alpha=alpha)
losses2 = p.fit(trainX, trainY, epochs=epochs)
# Out:
# training...
# epoch=  1 , loss=  0.12542773742768218
# epoch=  2 , loss=  0.21288762897228383
# epoch=  3 , loss=  0.14285946510241293
# epoch=  4 , loss=  0.16751557105898665
# epoch=  5 , loss=  0.059094863188341326
# epoch=  6 , loss=  0.03244761568906264
# epoch=  7 , loss=  0.00410533004038651
# epoch=  8 , loss=  0.03500749321201904
# epoch=  9 , loss=  0.008729230986998232
# epoch=  10 , loss=  0.0007831669891703228
# epoch=  11 , loss=  0.04186313222905088
# epoch=  12 , loss=  0.04298726503544285
# epoch=  13 , loss=  0.08630188667168028
# epoch=  14 , loss=  0.024884480591341615
# epoch=  15 , loss=  0.00085952355454732
# epoch=  16 , loss=  0.006342045132052412
# epoch=  17 , loss=  0.011600655745990772
# epoch=  18 , loss=  0.0015495139102757146
# epoch=  19 , loss=  0.001194919022655997
# epoch=  20 , loss=  0.0015050593015812448
# epoch=  21 , loss=  0.015993646754242183
# epoch=  22 , loss=  0.001290676710570572
# epoch=  23 , loss=  0.0013349573640504438
# epoch=  24 , loss=  0.016335036451864828
# epoch=  25 , loss=  0.001698822435227144
# epoch=  26 , loss=  0.08869409198667094
# epoch=  27 , loss=  0.010413773227924987
# epoch=  28 , loss=  0.0028325705946159628
# epoch=  29 , loss=  0.0004897267455901504
# epoch=  30 , loss=  0.03223615188021996
# epoch=  31 , loss=  0.00040470831125458156
# epoch=  32 , loss=  0.026860023054121506
# epoch=  33 , loss=  0.005938334162075864
# epoch=  34 , loss=  0.0011530661977536786
# epoch=  35 , loss=  0.004775569542568326
# epoch=  36 , loss=  0.013503500270054992
# epoch=  37 , loss=  0.005437335535973971
# epoch=  38 , loss=  0.0016641810825211978
# epoch=  39 , loss=  0.00020811264382871716
# epoch=  40 , loss=  0.00199957003472636
# epoch=  41 , loss=  0.03362589728824744
# epoch=  42 , loss=  0.011865813575602808
# epoch=  43 , loss=  0.013840027973288165
# epoch=  44 , loss=  0.01288778468650424
# epoch=  45 , loss=  0.00015138826969499184
# epoch=  46 , loss=  0.02491381254465861
# epoch=  47 , loss=  0.00033786147239396814
# epoch=  48 , loss=  0.0013148399604444652
# epoch=  49 , loss=  0.00024297579073300437
# epoch=  50 , loss=  0.0020611966309928027
# epoch=  51 , loss=  0.06279227417666991
# epoch=  52 , loss=  0.04106761575153746
# epoch=  53 , loss=  0.0013618773530593622
# epoch=  54 , loss=  0.0009536065587172234
# epoch=  55 , loss=  0.01688115636727597
# epoch=  56 , loss=  0.020192548145958902
# epoch=  57 , loss=  0.0032191999840327735
# epoch=  58 , loss=  0.004633065140856985
# epoch=  59 , loss=  0.002864426703978882
# epoch=  60 , loss=  0.009067061071155754
# epoch=  61 , loss=  0.0012142258080923534
# epoch=  62 , loss=  0.0006777215463350762
# epoch=  63 , loss=  0.00011312643378487652
# epoch=  64 , loss=  0.002825266328849516
# epoch=  65 , loss=  0.030191682547543747
# epoch=  66 , loss=  0.008771732336096655
# epoch=  67 , loss=  0.11006385303371775
# epoch=  68 , loss=  2.743152166359293e-06
# epoch=  69 , loss=  0.0006786043342460307
# epoch=  70 , loss=  0.009927495382829632
# epoch=  71 , loss=  0.00018439891591736716
# epoch=  72 , loss=  0.00413043776624611
# epoch=  73 , loss=  0.0007785779638911069
# epoch=  74 , loss=  0.0002934485955022671
# epoch=  75 , loss=  0.0025424505355238227
# epoch=  76 , loss=  0.05341415618135052
# epoch=  77 , loss=  2.29415378373427e-05
# epoch=  78 , loss=  2.7610226999414567e-05
# epoch=  79 , loss=  0.0062053424415191094
# epoch=  80 , loss=  0.05995739666781996
# epoch=  81 , loss=  0.000330169958648338
# epoch=  82 , loss=  8.708580808857187e-05
# epoch=  83 , loss=  0.00012451017152032335
# epoch=  84 , loss=  0.037966553832761284
# epoch=  85 , loss=  0.004403987576345515
# epoch=  86 , loss=  8.748660111377125e-05
# epoch=  87 , loss=  0.00031802601235875606
# epoch=  88 , loss=  0.005078762935064698
# epoch=  89 , loss=  0.0002981241276943988
# epoch=  90 , loss=  0.008512299421282909
# epoch=  91 , loss=  3.2645853402179426e-05
# epoch=  92 , loss=  0.014164889737988672
# epoch=  93 , loss=  0.00010460270116243546
# epoch=  94 , loss=  7.485988350556088e-05
# epoch=  95 , loss=  0.0005392217616928513
# epoch=  96 , loss=  0.03751012058237168
# epoch=  97 , loss=  5.2427702990631234e-05
# epoch=  98 , loss=  0.004492081000478363
# epoch=  99 , loss=  1.4555275935780134e-05
# epoch=  100 , loss=  0.0687407327812864

# %%
#plot the losses of both perceptrons
plt.plot(np.arange(0, len(losses2))/50, losses2)
plt.plot(np.arange(0, epochs), losses)
plt.title("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(np.arange(0, len(losses2))/50, losses2)

plt.title("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.show()
